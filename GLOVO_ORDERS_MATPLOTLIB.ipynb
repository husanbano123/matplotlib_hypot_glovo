# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Admin/Downloads/Glovo_Orders.csv",index_col=0)
df=pd.DataFrame(data)
df
# Out:
#      Order_ID  Customer_ID  Order_Value        Time_of_Order  Delivery_Time  \
# 0        1001          685    40.903413  2024-02-15 17:42:16             49
# 1        1002          560    38.818007  2024-02-03 07:26:10             25
# 2        1846          560    27.995043  2024-01-01 03:20:27             39
# 3        1003          630    36.783455  2024-02-05 18:46:58             34
# 4        1004          193    39.868494  2024-01-27 18:10:06             35
# ..        ...          ...          ...                  ...            ...
# 995      1995          967    42.932766  2024-01-20 12:53:48             39
# 996      1996          916    34.284789  2024-01-17 04:58:16             32
# 997      1997          163    49.316326  2024-01-07 09:22:37             38
# 998      1998           51    35.603175  2024-01-10 16:49:38             20
# 999      1999          243    16.592875  2024-01-02 16:48:19             42
#
# ...

# %%
df.describe()
# Out:
#           Order_ID  Customer_ID  Order_Value  Delivery_Time       Rating  \
# count  1000.000000  1000.000000  1000.000000    1000.000000  1000.000000
# mean   1500.500000   507.312000    32.667628      39.084000     2.908000
# std     288.819436   289.934218    10.367100      11.711537     1.436523
# min    1001.000000     1.000000    15.019109      20.000000     1.000000
# 25%    1250.750000   248.500000    24.066674      29.000000     2.000000
# 50%    1500.500000   516.500000    32.429238      38.000000     3.000000
# 75%    1750.250000   766.250000    41.917594      49.000000     4.000000
# max    2000.000000  1000.000000    49.993300      59.000000     5.000000
#
#               Age
# count  1000.00000
# mean     44.06300
# std      15.26224
# min      18.00000
# 25%      32.00000
# 50%      44.00000
# 75%      57.00000
# max      70.00000

# %%
df.skew()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_5688/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Order_ID         0.000000
# Customer_ID     -0.032686
# Order_Value      0.009478
# Delivery_Time    0.077307
# Rating           0.108868
# Age              0.016161
# dtype: float64

# %%
df.kurtosis()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_5688/615572439.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.kurtosis()
# Order_ID        -1.200000
# Customer_ID     -1.254049
# Order_Value     -1.232711
# Delivery_Time   -1.233244
# Rating          -1.318765
# Age             -1.105523
# dtype: float64

# %% [markdown]
# # Box Plot:
# 1.Box Plot is a statistical visualization tool that provides a summary of the distribution of a dataset.outliers are generally high and low values in the datasets.
#
# 2.It is particularly useful for identifying the central tendency, variability, and skewness of the data, as well as identifying potential outliers.
#
# 3.In Box plot we have to define only x_axis and Y_axis=obeservation value,x-axis should be numeric value not be categorical value.
#
# 4.The y-axis of a box plot represents the range of values of the variable being measured within each category or group.
#
# 5.Whiskers: The whiskers extend from the edges of the box to the maximum and minimum data points within 1.5 times the IQR from the quartiles. Data points beyond the whiskers are considered potential outliers.
#
# 6.we plotted the boxplot for numeric values and it dosn't contain any outliers.because there are no data point beyond the whiskers.
# eg:salary comparison(if we want compare salaries of  employee across different deparments),housing prices,exam scores,Customer ratings,temprature variability,time seriese analysis.

# %%
a=df['Order_ID']#'Customer_ID','Order_Value','Delivery_Time','Rating','Age'
plt.subplot(2,3,1)
plt.boxplot(a)
plt.title(" 'Order_ID'")

b=df['Customer_ID']
plt.subplot(2,3,2)
plt.boxplot(b)
plt.title("'Customer_ID'")

c=df['Order_Value']
plt.subplot(2,3,3)
plt.boxplot(c)
plt.title("'Order_Value'")

d=df['Delivery_Time']
plt.subplot(2,3,4)
plt.boxplot(d)
plt.title("'Delivery_Time'")

e=df['Rating']
plt.subplot(2,3,5)
plt.boxplot(e)
plt.title("'Rating'")

f=df['Age']
plt.subplot(2,3,6)
plt.boxplot(f)
plt.title("'Age'")

plt.show()

# %% [markdown]
# # Bar Chart:
#  1.A bar chart is a type of graph that represents categorical data with rectangular bars.
#
#  2.The x-axis should be categorical data and y_axis should be numerical data.
#  eg.number of student in each grade level,percentage of people who prefer different types of food(pizza,momos,noodles),sales figure for different product categories(Elctronics,Clothing,Home decore etc).

# %%
x=df['Membership_Type']
y=df['Order_Value']
plt.bar(df['Membership_Type'].unique(),df.groupby('Membership_Type')['Order_Value'].sum(),color='green')
plt.ylabel('Order_Value')
plt.xlabel('Membership_Type')
plt.title('Bar plot on Mebershiptype by ordervalue ')

plt.show()

# %%
print(df['Membership_Type'].value_counts())
print(df['Order_Value'].mean())
# Out:
# Regular    502
# Premium    498
# Name: Membership_Type, dtype: int64
# 32.66762833485086

# %%
x=df['Rating']
y=df['Order_Value']
plt.bar(df['Rating'].unique(),df.groupby('Rating')['Order_Value'].sum(),color='yellow')
plt.ylabel('Order_Value')
plt.xlabel('Rating')
plt.title('Bar grapgh on rating by order_value')
plt.grid(axis='x')
plt.show()

# %%
x=df['Gender']
y=df['Order_Value']
plt.barh(df['Gender'].unique(),df.groupby("Gender")["Order_Value"].sum(),height=0.1,color='red')
#plt.grid()
plt.ylabel("Order_Value")
plt.xlabel("Gender")
plt.title("Horizontal bar graph on Gender by Order_Value")
plt.show()

# %% [markdown]
# # Line plot:
# 1.also known as a line graph, is a type of data visualization that displays data points as individual markers (often dots) connected by lines. It is typically used to show the relationship between two variables over a continuous interval or time period
#
# 2.Line plots are particularly useful for displaying trends or patterns in data.
#
# 3.the x-axis represent the independent variable, while the y-axis represents the dependent variable. Both axes can accommodate numerical values, and in some cases, the x-axis may also represent categorical variables.and also y-axis may represent categorical .
#
# 4.X-axis: The categories representing the different types of marketing campaigns (e.g., Online Ads, TV Commercials, Print Ads).
# Y-axis: The categories representing the sales performance levels (e.g., Low, Medium, High).
#
# 5.these are the few example of line plot where x,y both are continuous variable and x could be categorical y could be continuous:
# 1.Stock Market analysis
# 2.Temprature Trends
# 3.Population Growth
# 4.Sales Trends
# 5.Weather patterns

# %%
#line plot of two continuous variable
x=df['Rating'].head(10)
y=df['Order_Value'].head(10)
plt.title("Line Plot")
plt.ylabel("Order_Value")
plt.xlabel("Order_ID")
plt.plot(x,y)

# %%
#line plot of one categorical and one continuous variable
x=df['Membership_Type'].head(10)
y=df['Rating'].head(10)
plt.plot(x,y)
plt.title("Line Plot Catehorical")
plt.ylabel("Custpmer_ID")
plt.xlabel("Location")
# Out:
# Text(0.5, 0, 'Location')

# %%
#line plot of two categorical variable
x=df['Gender'].head()
y=df['Special_Discounts_Applied'].head()
plt.plot(x,y)

# %% [markdown]
# # Pie Chart:
# 1.A pie chart is a circular statistical graphic that is divided into slices to illustrate numerical proportions.how different categories contribute to the overall distribution or total
#
# 2.The categories are represented around the circumference of the circle, and the proportions are shown by the size of the slices.(i.e x)
#
# 3.eg of pie chart is:
# a company wants to visualize its quarterly revenue breakdown by product categories.
# (Electronics etc)
# 1.Market Share:
# 2.each segment of pie represnt  the percentage of market held by a perticular company or product.
# 3.Budget Allocation:Pie charts can be used to visualize how a budget is allocated across different categories, such as education, healthcare, transportation, etc.
# 4.Product Sales Distribution: the distribution of sales across different product categories. Each segment of the pie represents the percentage of total sales attributed to a specific product or category.

# %%
y=df['Order_Value'].head(10)
mylabels=df['Gender'].head(10)
#mycolors=['Red','black','hotpink','Yellow','Green']
plt.pie(y,labels=mylabels)
plt.title('Pie chart on Order_Value by Gender')
plt.show()

# %%
y=df['Special_Discounts_Applied'].value_counts()
mylabels=['Yes','No']
plt.title("Pie chart on SPecial_Discounts_Applied")
plt.pie(y,labels=mylabels)
plt.show()

# %%
x=df['Gender'].value_counts()
mylabels=['Female','Male',"Other"]
plt.pie(x,labels=mylabels)
plt.title("Pie chart on Gender Column")
plt.show()

# %% [markdown]
# # Scatter Plot:
# 1.A scatter plot is a type of data visualization that displays the relationship between two continuous variables.
#
# 2.Independent Variable (X-axis): The independent variable, also known as the predictor or explanatory variable, is typically plotted along the x-axis. This variable is usually the one that you can control or manipulate in an experiment or study.
# Dependent Variable (Y-axis): The dependent variable, also known as the response variable, outcome variable, or target variable, is typically plotted along the y-axis. This variable is usually the one that you're interested in understanding how it changes in response to changes in the independent variable.
#
# example of scatter plot:
# 1.Correlation Analysis: Scatter plots are often used to examine the relationship between two variables to determine if there is a correlation between them.
# 2.Regression Analysis:to predict the best fir line ,you might use a scatter plot to fit a regression line to predict house prices based on the size of the house.
# 3.Pattern Recognition: Scatter plots can be used to identify patterns or trends in the data, such as clusters of data points or non-linear relationships between variables.

# %%
x=df['Age']
y=df['Customer_ID']
plt.scatter(x,y,color='red')
plt.ylabel('Customer_ID')
plt.xlabel('Age')
plt.title("Scatter Plot on Age by Customer_ID")
plt.show()

# %% [markdown]
# # Histogram:
# 1.A histogram is a graph showing frequency distributions.displays the distribution of a continuous variable. It consists of a series of contiguous rectangular bars, where the height of each bar corresponds to the frequency or relative frequency of values within a specific interval, also known as a "bin."
#
# 2.It is a graph showing the number of observations within each given interval.
#
# 3.Histograms are particularly useful for visualizing the distribution of numerical data and understanding the central tendency, variability, and shape of the distribution. They provide insights into how the data is spread out across different ranges or intervals.
#
# 3.examples of Histogram is:
# 1.Temprature distribution:Each bar would represent a range of temperatures (e.g., 50-60°F, 61-70°F, etc.), with the height indicating the frequency of days with temperatures falling within each range.
# 2.Exams Score:Each bar in the histogram represents a range of scores (e.g., 0-10, 11-20, etc.), and the height of each bar represents the number of students who scored within that range.
# 3.Customer Wait time:Each bar would represent a range of wait times (e.g., 0-5 minutes, 6-10 minutes, etc.), with the height indicating the frequency of customers experiencing each wait time.

# %%
x=df['Order_Value'].head(50)
#x1=np.random.uniform(x)
plt.xlabel('Order_Value')
plt.ylabel('Count of Order_Value')
plt.title("Histogram on Order_Value")
plt.hist(x,color='purple')
plt.show()

# %%
y=[]
for i in range(50):
    x1=np.random.normal()
    y.append(x1)

# %%
y
# Out:
# [-1.027964711672341,
#  -2.3602691717379134,
#  0.203400378679825,
#  0.39513299850141287,
#  -0.8631205835437993,
#  -0.6703422078316775,
#  -0.6632054493795716,
#  -1.8251434183018171,
#  -0.5097368376510713,
#  -0.07602195793592345,
#  -1.0703366743548595,
#  0.37962874407834324,
#  0.1640465354813649,
#  0.024803498299355204,
#  -0.33503283319642,
#  0.9618861309750422,
#  -2.0631594012835484,
#  -0.5190433585685721,
#  -0.5485303199129213,
#  0.03437819548465708,
#  -1.2009851127637028,
#  1.2877012248153092,
#  -0.34749523174965335,
#  0.7904130215984595,
#  0.03782890357554051,
#  -0.2658835139940042,
#  -0.570314610967851,
#  -1.0183914166965637,
#  0.8311037687521668,
#  1.0564922621504458,
#  0.8819890973886,
#  -0.5156424690796888,
#  -1.588699639931148,
#  -0.5782856032766377,
#  -0.4233502257143573,
#  -0.3219230599692064,
#  -1.219278786810947,
#  0.7480547017278734,
#  -1.0739211742908679,
#  0.5887777788480852,
#  0.3450308533819522,
#  -0.83758434941485,
# ...

# %%
y1=pd.DataFrame(y)
y1.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Annotate Equation:
# annotate()	it is use to write comments on the graph at the specified position.
#
# figure(figsize = (x, y))	whenever we want the result to be displayed in a separate window we use this command, and figsize argument decides what will be the initial size of the window that will be displayed after the run

# %%
x=df['Special_Discounts_Applied'].head(10)
y=df['Customer_ID'].head(10)
plt.bar(x,y)
#Annotation
plt.text(2, 0,r'equation: $\sum_{i=0}^\infty x_i$', fontsize=12)
#save the graph
plt.savefig('viz_1.png')
plt.show()

# %%
x=df['Customer_ID']
y=df['Delivery_Time']
plt.scatter(x,y,marker='*',color="Orange")
#Annotation
plt.text(0, 0,r'equation: $\sum_{i=0}^\infty x_i$', fontsize=12)
plt.ylabel("Delivery_Time")
plt.xlabel('Customer_ID')
plt.title('Scatter Plot on Customer_ID by Delivery_Time')
#save the graph
plt.savefig('viz_1.png')
plt.show()

# %%
x=df['Age'].head(10)
y=df['Order_Value'].head(10)
plt.title("line plot on Age and Ordervalue")
plt.plot(x, y)
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)


plt.show()

# %%
df['Age'].sum()
# Out:
# 44063

# %% [markdown]
# # Markers

# %%
x=df['Customer_ID'].head(10)
y=df['Delivery_Time'].head(10)
plt.plot(x,y,marker='o')
plt.ylabel('Delivery_Time')
plt.xlabel('Customer_ID')
plt.title('Line Plot on customerid by deliverytime')
plt.show()

# %% [markdown]
# # ## Marker Format Strings fmt
#
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color
#
#     '-'	Solid line
#     ':'	Dotted line
#     '--'	Dashed line
#     '-.'	Dashed/dotted line
#
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:
#
# ms = marker size
#
# mec = marker edge color

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Order_Value', 'Time_of_Order',
#        'Delivery_Time', 'Rating', 'Special_Discounts_Applied', 'Age', 'Gender',
#        'Location', 'Membership_Type'],
#       dtype='object')

# %%
x=df['Customer_ID'].head()
y=df['Age'].head()
plt.plot(x,y,'o:r', ms = 20, mec = 'r', mfc = 'black')

# %%
x=df['Delivery_Time'].head()
y=df['Order_Value'].head()
plt.ylabel("Oder_Value")
plt.xlabel("Delivery_Time")
plt.title('Line Plot by dash dotted line with marker edge color')
plt.plot(x,y,'*-.b', ms = 20, mec = 'r', mfc = 'black')

# %% [markdown]
# #xticks()	it decides how the markings are to be made on the x-axis
# yticks()	it decides how the markings are to be made on the y-axis
#
# gca().legend()	pass a list as it’s arguments of all the plots made, if labels are not explicitly specified then add the values in the list in the same order as the plots are made
#
# set_xticks	it is used to set the range and the step size of the markings on x – axis in a subplot
#
# set_yticks	it is used to set the range and the step size of the markings on y – axis in a subplot
#
# gca()	it helps to get access over the all the four axes of the graph
#
# gca().spines [‘right/left/top/bottom’].set_visible(True/False)	it access the individual spines or the individual boundaries and helps to change theoir visibility

# %% [markdown]
# # Axis method
# the axis method in Matplotlib provides control over various aspects of the axes, allowing for customization and enhancement of plots according to specific requirements.

# %%
x=df['Delivery_Time'].head(10)
y=df['Order_Value'].head(10)
plt.plot(x,y)
plt.axis([30,37,37,40])#(xmin,xmax,ymin,ymax)
plt.show()

# %%
plt.plot(x,y)

# %% [markdown]
# #  xticks(), yticks(), gca() ie get current axes, set_xlim, set_ylim Methods
# 1.gac(get current access)-where we can see the graph in the form of zoom in and zoom out.
#
# 2.gca() stands for "get current axes". It's a function that returns the current axes instance being plotted on. Understanding gca() is essential for accessing and modifying properties of the current plot axes.
#
# 3.You can use gca() to access properties of the current axes, such as limits, labels, ticks, etc

# %%
fig=plt.figure(figsize=(6,6))
x=df['Order_Value']
#y=df['Customer_ID']
#y=df['']
plt.plot(x,x, color='black', marker=None)
# put labels for all ticks
labels = np.arange(20,52,2)   # start, stop, step / try changing 1 to 2
plt.xticks(labels, labels)
plt.yticks(labels, labels)

# set limits of axis
# here GCA means (get current axes)
ax = plt.gca() #we can zoom in zoom out the data points
ax.set_xlim([20,48])        # setting x tick limit
ax.set_ylim([20,48])
plt.title("Annotate Specific point on Order_Value data")
# Annotate with text + Arrow
plt.annotate('This point is interesting!', xy=(22,24), xytext=(22, 40), arrowprops=dict(facecolor='red'))
                     # Label                   #Coordinate               #custom Arrow  

plt.show()
labels
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50])

# %% [markdown]
# # Annotate changing the parameters:
#
# which can be helpful for highlighting specific points of interest or adding explanatory text to a visualization. It's commonly used in data analysis and presentation to draw attention to important aspects of the data.

# %%
fig=plt.figure(figsize=(6,6))
x=df['Order_Value']
#y=df['Customer_ID']
#y=df['']
plt.plot(x,x, color='red', marker=None)
# put labels for all tick|+_   # start, stop, step / try changing 1 to 2
plt.xticks(labels, labels)
plt.yticks(labels, labels)

# set limits of axis
# here GCA means (get current axes)
ax = plt.gca() #we can zoom in zoom out the data points
ax.set_xlim([20,48])        # setting x tick limit
ax.set_ylim([20,48])

# Annotate with text + Arrow
plt.annotate('This point is interesting!', xy=(24,20), xytext=(22, 32), arrowprops=dict(facecolor='black'))
                     # Label                   #Coordinate               #custom Arrow  

plt.show()
labels
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50])

# %% [markdown]
# # One sample
# the avg rating is above 3.0.(note the given data is of sample  where mean=2.9 which is sample mean)
# H0=mu(mean of population)<=3.0
# H1=mu>3.0

# %%
ratings=df['Rating']
t_stats,p_value=stats.ttest_1samp(ratings,popmean=3.0)
alpha=0.05

# %%
p_value/2>alpha
# Out:
# False

# %%
t_stats
# Out:
# -2.0252335340763326

# %%
p_value/2
# Out:
# 0.021554450040164354

# %%
if p_value/2<alpha:
    print("Rejecting Null Hypothesis suggesting avg ratings is sifnifically more than 3.0")
else:
    print("Fail to Reject Null Hypothesis H0 suggesting avg ratings is sifnifically les than 3.0")
print("Accept alternate Hypoyhesis H1")
# Out:
# Rejecting Null Hypothesis suggesting avg ratings is sifnifically more than 3.0
# Accept alternate Hypoyhesis H1

# %% [markdown]
# # independant sample
# 2.Two tailed test:
# comparing mean of 2 independant samples i.e "rating" of premium  vs regular
# H0= no significant difference in rating between regular and premium
# H1= there is significance difference in rating between regular and premium

# %%
regular_ratings=df[df['Membership_Type']=="Regular"]["Rating"]
premium_ratings=df[df['Membership_Type']=="Premium"]["Rating"]

# %%
regular_ratings
# Out:
# 1      5
# 2      2
# 4      3
# 5      3
# 14     1
#       ..
# 992    2
# 993    1
# 996    4
# 997    3
# 998    3
# Name: Rating, Length: 502, dtype: int64

# %%
premium_ratings
# Out:
# 0      3
# 3      5
# 6      3
# 7      4
# 8      4
#       ..
# 989    1
# 990    5
# 994    3
# 995    1
# 999    4
# Name: Rating, Length: 498, dtype: int64

# %%
t_stats1,p_val1=stats.ttest_ind(regular_ratings,premium_ratings)
print("\nTwo_tailed test results:")
print("T_statistics:",t_stats1)
print("P_value: ",p_val1)
alpha=0.05
# Out:
# Two_tailed test results:
# T_statistics: 0.6683233532565014
# P_value:  0.5040817460792615

# %%
p_val1>alpha
# Out:
# True

# %%
if p_val1<alpha:
    print("Reject null hypothesis H0,suggesting there is significant difference in rating between regular and premium")
else:
    print("Fail to reject null hypo H0,suggesting there is no significant difference in rating between regular and premium")
# Out:
# Fail to reject null hypo H0,suggesting there is no significant difference in rating between regular and premium

# %% [markdown]
# #  Anova sample
# 1.ONE WAY ANOVA
#
# whether there are any statistically significant difference between the means of multiple groups(Gender in this case)
#
# H0=no significant difference in means among the Gender in terms of Age
# H1= at least one dish has a different mean in terms of Age

# %%
female_age=df[df["Gender"]=="Female"]["Age"]
male_age=df[df["Gender"]=="Male"]["Age"]
other_age=df[df["Gender"]=="Other"]["Age"]

# %%
f_stat,p_val=stats.f_oneway(female_age,male_age,other_age)
print("\nANOVA Results:")
print("F_statistics:",f_stat)
print("P_value: ",p_val)
alpha=0.05
# Out:
# ANOVA Results:
# F_statistics: 2.604689764872438
# P_value:  0.07442908003353252

# %%
p_val>alpha
# Out:
# True

# %%
if p_val<alpha:
    print("Reject null hypothesis ,suggesting at least one Gender has significant difference in Age between male,female and others")
else:
    print("Fail to Reject null hypothesis H0,suggesting there is no significant difference in Age between Genders")
# Out:
# Fail to Reject null hypothesis H0,suggesting there is no significant difference in Age between Genders

# %% [markdown]
# # paired Sample:
#
# paired sample is not possible in this dataset because there is no such observation present in which two samples are related in some way for example:before delivery_time and after delivery_time.

# %%
deliver_time=df["Delivery_Time"]
ordered_time=df["Time_of_Order"]
